# %% [markdown]
# # 1. Importing Libraries and Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

df = pd.read_csv("loan_default.csv")
df.dropna(inplace=True)
df.head()
# Out:
#       ID  year loan_limit Gender approv_in_adv loan_type loan_purpose  \
# 2  24892  2019         cf   Male           pre     type1           p1
# 4  24894  2019         cf  Joint           pre     type1           p1
# 5  24895  2019         cf  Joint           pre     type1           p1
# 6  24896  2019         cf  Joint           pre     type1           p3
# 8  24898  2019         cf  Joint         nopre     type1           p3
#
#   Credit_Worthiness open_credit business_or_commercial  ...  credit_type  \
# 2                l1        nopc                  nob/c  ...          EXP
# 4                l1        nopc                  nob/c  ...         CRIF
# 5                l1        nopc                  nob/c  ...          EXP
# 6                l1        nopc                  nob/c  ...          EXP
# 8                l1        nopc                  nob/c  ...          CIB
#
#    Credit_Score  co-applicant_credit_type    age  submission_of_application  \
# 2           834                       CIB  35-44                    to_inst
# 4           602                       EXP  25-34                   not_inst
# 5           864                       EXP  35-44                   not_inst
# 6           860                       EXP  55-64                    to_inst
# 8           580                       EXP  55-64                    to_inst
#
#          LTV   Region Security_Type  Status dtir1
# 2  80.019685    south        direct       0  46.0
# 4  91.886544    North        direct       0  39.0
# 5  70.089286    North        direct       0  40.0
# 6  79.109589    North        direct       0  44.0
# 8  78.765690  central        direct       0  44.0
#
# [5 rows x 34 columns]

# %% [markdown]
# # 2. Dataset Shape and Summary Statistics

# %%
# Shape and summary
print("Rows:", df.shape[0], "Columns:", df.shape[1])
df.describe(include='all').T
# Out:
# Rows: 98187 Columns: 34
#                              count unique       top   freq           mean  \
# ID                         98187.0    NaN       NaN    NaN   99115.912524
# year                       98187.0    NaN       NaN    NaN         2019.0
# loan_limit                   98187      2        cf  92399            NaN
# Gender                       98187      4     Joint  29110            NaN
# approv_in_adv                98187      2     nopre  81254            NaN
# loan_type                    98187      3     type1  82223            NaN
# loan_purpose                 98187      4        p3  39231            NaN
# Credit_Worthiness            98187      2        l1  94428            NaN
# open_credit                  98187      1      nopc  98187            NaN
# business_or_commercial       98187      2     nob/c  88074            NaN
# loan_amount                98187.0    NaN       NaN    NaN  333657.464838
# rate_of_interest           98187.0    NaN       NaN    NaN       4.078418
# Interest_rate_spread       98187.0    NaN       NaN    NaN       0.466075
# Upfront_charges            98187.0    NaN       NaN    NaN    3389.206553
# term                       98187.0    NaN       NaN    NaN     333.658448
# Neg_ammortization            98187      2   not_neg  90328            NaN
# interest_only                98187      2   not_int  94120            NaN
# lump_sum_payment             98187      2  not_lpsm  97504            NaN
# property_value             98187.0    NaN       NaN    NaN  508851.538391
# construction_type            98187      1        sb  98187            NaN
# occupancy_type               98187      3        pr  91192            NaN
# Secured_by                   98187      1      home  98187            NaN
# total_units                  98187      4        1U  96894            NaN
# income                     98187.0    NaN       NaN    NaN    7196.317028
# credit_type                  98187      4       CIB  36438            NaN
# Credit_Score               98187.0    NaN       NaN    NaN     699.505383
# co-applicant_credit_type     98187      2       CIB  53755            NaN
# age                          98187      7     45-54  23205            NaN
# submission_of_application    98187      2   to_inst  59750            NaN
# LTV                        98187.0    NaN       NaN    NaN      71.005978
# Region                       98187      4     North  51124            NaN
# Security_Type                98187      1    direct  98187            NaN
# Status                     98187.0    NaN       NaN    NaN            0.0
# dtir1                      98187.0    NaN       NaN    NaN       37.37505
#
#                                      std       min        25%        50%  \
# ID                           42951.31409   24892.0    61770.0    99118.0
# year                                 0.0    2019.0     2019.0     2019.0
# loan_limit                           NaN       NaN        NaN        NaN
# Gender                               NaN       NaN        NaN        NaN
# approv_in_adv                        NaN       NaN        NaN        NaN
# loan_type                            NaN       NaN        NaN        NaN
# loan_purpose                         NaN       NaN        NaN        NaN
# Credit_Worthiness                    NaN       NaN        NaN        NaN
# open_credit                          NaN       NaN        NaN        NaN
# business_or_commercial               NaN       NaN        NaN        NaN
# loan_amount                175041.874642   26500.0   206500.0   306500.0
# rate_of_interest                0.534448     2.125       3.75       3.99
# Interest_rate_spread            0.484145    -1.039      0.103      0.399
# Upfront_charges              3279.884804       0.0      822.0    2800.91
# term                           60.276585      96.0      360.0      360.0
# Neg_ammortization                    NaN       NaN        NaN        NaN
# interest_only                        NaN       NaN        NaN        NaN
# lump_sum_payment                     NaN       NaN        NaN        NaN
# property_value             343045.549076   28000.0   288000.0   438000.0
# construction_type                    NaN       NaN        NaN        NaN
# occupancy_type                       NaN       NaN        NaN        NaN
# Secured_by                           NaN       NaN        NaN        NaN
# total_units                          NaN       NaN        NaN        NaN
# income                       6201.713331     120.0     4020.0     6000.0
# credit_type                          NaN       NaN        NaN        NaN
# Credit_Score                  115.671035     500.0      599.0      699.0
# co-applicant_credit_type             NaN       NaN        NaN        NaN
# age                                  NaN       NaN        NaN        NaN
# submission_of_application            NaN       NaN        NaN        NaN
# LTV                            18.119402  3.083554  59.645062  73.840206
# Region                               NaN       NaN        NaN        NaN
# Security_Type                        NaN       NaN        NaN        NaN
# Status                               0.0       0.0        0.0        0.0
# dtir1                          10.027001       5.0       31.0       38.0
#
#                                  75%         max
# ID                          136261.5    173559.0
# year                          2019.0      2019.0
# loan_limit                       NaN         NaN
# Gender                           NaN         NaN
# approv_in_adv                    NaN         NaN
# loan_type                        NaN         NaN
# loan_purpose                     NaN         NaN
# Credit_Worthiness                NaN         NaN
# open_credit                      NaN         NaN
# business_or_commercial           NaN         NaN
# loan_amount                 436500.0   3006500.0
# rate_of_interest                 4.5         8.0
# Interest_rate_spread          0.7748       3.357
# Upfront_charges               4982.5     60000.0
# term                           360.0       360.0
# Neg_ammortization                NaN         NaN
# interest_only                    NaN         NaN
# lump_sum_payment                 NaN         NaN
# property_value              638000.0   6908000.0
# construction_type                NaN         NaN
# occupancy_type                   NaN         NaN
# Secured_by                       NaN         NaN
# total_units                      NaN         NaN
# income                        8760.0    377220.0
# credit_type                      NaN         NaN
# Credit_Score                   800.0       900.0
# co-applicant_credit_type         NaN         NaN
# age                              NaN         NaN
# submission_of_application        NaN         NaN
# LTV                        83.805031  136.538462
# Region                           NaN         NaN
# Security_Type                    NaN         NaN
# Status                           0.0         0.0
# dtir1                           44.0        61.0

# %% [markdown]
# # 3. Loan Status by Region

# %%
sns.countplot(data=df, x='Region', hue='Status', palette='coolwarm')
plt.title("Loan Status by Region")
plt.show()

# %% [markdown]
# # 4. Loan Status by Credit Worthiness

# %%
sns.countplot(data=df, x='Credit_Worthiness', hue='Status', palette='Set3')
plt.title("Loan Status by Credit Worthiness")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 5. Loan Status by Gender

# %%
sns.countplot(data=df, x='Gender', hue='Status', palette='pastel')
plt.title("Loan Status by Gender")
plt.show()

# %% [markdown]
# # 6. Credit Score Distribution

# %%
sns.histplot(df['Credit_Score'], kde=True, bins=30, color='skyblue')
plt.title("Credit Score Distribution")
plt.show()

# %% [markdown]
# # 7. Debt-to-Income Ratio by Status

# %%
sns.violinplot(data=df, x='Status', y='dtir1', palette='muted')
plt.title("Debt-to-Income Ratio by Status")
plt.show()

# %% [markdown]
# # 8. Loan to Value (LTV) by Loan Status

# %%
sns.boxplot(data=df, x='Status', y='LTV', palette='Set1')
plt.title("Loan to Value (LTV) by Loan Status")
plt.show()

# %% [markdown]
# # 9. Correlation Heatmap

# %%
# Select numeric columns
numeric_df = df[['Credit_Score', 'LTV', 'dtir1']]

# Convert Status to numeric
df['Status_code'] = df['Status'].astype(int)  # Already 0/1

plt.figure(figsize=(8,6))
sns.heatmap(df[['Credit_Score', 'LTV', 'dtir1', 'Status_code']].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # 10. Submission Type vs Loan Status

# %%
sns.countplot(data=df, x='submission_of_application', hue='Status', palette='pastel')
plt.title("Submission Type vs Loan Status")
plt.show()
